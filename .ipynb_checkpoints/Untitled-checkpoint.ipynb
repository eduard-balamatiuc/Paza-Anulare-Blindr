# %%
import pandas as pd

# %%
COLUMN_NAMES = ['login', 'password', 'key', 'email', 'name', 'age', 'city', 'spend_time', 'movies', 'music', 'pet', 'profession', 'hobbies', 'social_status', 'gender', 'food','image_embedding', 'description', 'reviews', 'points']
PATH_TO_DATA = 'db.csv'

# %%
db = pd.read_csv(PATH_TO_DATA)

# %%
db
# Out:
#   login password                                   key  \
# 0  geek    12345  35b16241-2de5-4e58-84c3-49f0e82cf937
# 1  deep     qqqq  cdea1c4c-6937-464f-866d-bb0decc422e0
# 2    mf      789  ba4ec21b-7636-4453-aa6b-d55f7d096d47
#
#                      email        name  age      city spend_time  \
# 0   moglanmihai7@gmail.com       Mihai   22  Chisinau   actively
# 1  moglan.mihai@isa.utm.md        Alex    9  Chisinau   actively
# 2    graur.lenka@gmail.com  Mr.Crowley   21     Cahul   actively
#
#                              movies                       music  pet  \
# 0  [['Comedy', 'Mystery', 'Anime']]    [['Rock', 'Indie Rock']]   No
# 1  ['Comedy', 'Horror', 'Thriller']  ['Rock', 'Country', 'Pop']  Yes
# 2                     [['Western']]       [['Rock', 'Dubstep']]  Yes
#
#                profession                              hobbies social_status  \
# 0  Information Technology        [['Video Games', 'Podcasts']]          Wedd
# 1             Agriculture    ['Reading', 'Playing boardgames']          Wedd
# 2             Agriculture  [['Reading', 'Playing boardgames']]        Single
#
#    gender                         food  \
# 0    Male           [['Healthy food']]
# 1  Female  ['Healthy food', 'Seafood']
# 2   Other              [['Junk food']]
#
#                                      image_embedding  \
# 0  [ 0.7244092  -0.17755634 -0.78186446  0.108706...
# 1  [ 0.7244092  -0.17755634 -0.78186446  0.108706...
# 2  [ 0.7244092  -0.17755634 -0.78186446  0.108706...
#
#                                     description  reviews  points
# 0  I like robotics and food and fucking carrots      NaN     NaN
# 1                     I love cooking and tennis      NaN     NaN
# 2       I like potatoes and playing in the soil      NaN     0.0

# %%
db = pd.DataFrame({}, columns = COLUMN_NAMES)

# %%
db.to_csv(PATH_TO_DATA, index = False)

# %%
db = db.drop([3, 4])

# %%
db = pd.read_csv(PATH_TO_DATA)

# %%
db
# Out:
#   login password                                   key  \
# 0  geek    12345  35b16241-2de5-4e58-84c3-49f0e82cf937
# 1  deep     qqqq  cdea1c4c-6937-464f-866d-bb0decc422e0
#
#                      email   name  age      city spend_time  \
# 0   moglanmihai7@gmail.com  Mihai   22  Chisinau   actively
# 1  moglan.mihai@isa.utm.md   Alex    9  Chisinau   actively
#
#                              movies                       music  pet  \
# 0  [['Comedy', 'Mystery', 'Anime']]    [['Rock', 'Indie Rock']]   No
# 1  ['Comedy', 'Horror', 'Thriller']  ['Rock', 'Country', 'Pop']  Yes
#
#                profession                            hobbies social_status  \
# 0  Information Technology      [['Video Games', 'Podcasts']]          Wedd
# 1             Agriculture  ['Reading', 'Playing boardgames']          Wedd
#
#    gender                         food  \
# 0    Male           [['Healthy food']]
# 1  Female  ['Healthy food', 'Seafood']
#
#                                      image_embedding  \
# 0  [ 0.7244092  -0.17755634 -0.78186446  0.108706...
# 1  [ 0.7244092  -0.17755634 -0.78186446  0.108706...
#
#                  description  reviews
# 0   I like robotics and food      NaN
# 1  I love cooking and tennis      NaN
